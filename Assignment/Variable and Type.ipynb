# %%
a = 12
b = 6
print(a+b)
print(a-b)
print(a*b)
print(a/b)
# Out:
# 18
# 6
# 72
# 2.0

# %%
a = 12
b = 6
print("The value of",a,"+",6,"is:",a+b)
print("The value of",a,"-",6,"is:",a-b)
print("The value of",a,"*",6,"is:",a*b)
print("The value of",a,"/",6,"is:",a/b)
# Out:
# The value of 12 + 6 is: 18
# The value of 12 - 6 is: 6
# The value of 12 * 6 is: 72
# The value of 12 / 6 is: 2.0

# %%
a = 1
b = True
c = "Bibika"
d = None
print(type(a))
print(type(b))
print(type(c))
print(type(d))
# Out:
# <class 'int'>
# <class 'bool'>
# <class 'str'>
# <class 'NoneType'>
