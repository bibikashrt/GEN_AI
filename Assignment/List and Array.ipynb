# %%
x = [1,2,3,4] 
print(x)
# Out:
# [1, 2, 3, 4]

# %%
y = [1,2,"Hello",3,True]
print(y)
# Out:
# [1, 2, 'Hello', 3, True]

# %%
print("Hello World")
# Out:
# Hello World

# %%
x = [9,12,7,4,11]
x.append(8)
x.sort()
print(x)
# Out:
# [4, 7, 8, 9, 11, 12]

# %%
my_array = [7, 12, 9, 4, 11, 8]
minVal = my_array[0]

for i in my_array:
  if i < minVal:
    minVal = i

print('Lowest value:', minVal)
# Out:
# Lowest value: 4
